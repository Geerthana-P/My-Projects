# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
# 1. Create a Population (for demonstration)
# -------------------------------------------------------------
# Let's assume a non-normal population (skewed)
population = np.random.exponential(scale=50, size=100000)

# Population mean for reference (not used in CI calculation)
true_population_mean = population.mean()

print("True Population Mean (just for comparison):", true_population_mean)
# Out:
# True Population Mean (just for comparison): 49.95254584315851

# %%
# 2. Take a Random Sample
# -------------------------------------------------------------

sample_size = 100
sample = np.random.choice(population, sample_size)

sample_mean = np.mean(sample)
sample_std = np.std(sample, ddof=1)  # sample standard deviation

print("\nSample Mean:", sample_mean)
print("Sample Standard Deviation:", sample_std)
# Out:
# Sample Mean: 47.31442513405127
# Sample Standard Deviation: 50.35801098750941

# %%
# 3. Calculate 95% Confidence Interval
# -------------------------------------------------------------
# Formula: mean ± z * (std / sqrt(n))
z_score = 1.96  # for 95% confidence
margin_of_error = z_score * (sample_std / np.sqrt(sample_size))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("\n95% Confidence Interval for the Population Mean:")
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# 95% Confidence Interval for the Population Mean:
# Lower Bound: 37.44425498049942
# Upper Bound: 57.184595287603116

# %%
# 4. Display Results Clearly
# -------------------------------------------------------------

ci_df = pd.DataFrame({
    "Statistic": ["Sample Mean", "Lower 95% CI", "Upper 95% CI"],
    "Value": [sample_mean, lower_bound, upper_bound]
})

ci_df
# Out:
#       Statistic      Value
# 0   Sample Mean  47.314425
# 1  Lower 95% CI  37.444255
# 2  Upper 95% CI  57.184595
