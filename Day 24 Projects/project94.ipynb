# %%
import pandas as pd

# %%
data = {
    "age": [25, 30, None, 40, None],
    "salary": [50000, None, 42000, None, 60000],
    "city": ["Delhi", None, "Mumbai", "Chennai", None],
    "gender": ["M", "F", None, "M", "F"]
}

df = pd.DataFrame(data)

print("Original Dataset (with missing values):")
print(df)
# Out:
# Original Dataset (with missing values):
#     age   salary     city gender
# 0  25.0  50000.0    Delhi      M
# 1  30.0      NaN     None      F
# 2   NaN  42000.0   Mumbai   None
# 3  40.0      NaN  Chennai      M
# 4   NaN  60000.0     None      F

# %%
print("\nMissing values before imputation:")
print(df.isnull().sum())
# Out:
# Missing values before imputation:
# age       2
# salary    2
# city      2
# gender    1
# dtype: int64

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

print("\nNumerical Columns:", list(num_cols))
print("Categorical Columns:", list(cat_cols))
# Out:
# Numerical Columns: ['age', 'salary']
# Categorical Columns: ['city', 'gender']

# %%
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_9456\3421764164.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_9456\3421764164.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)

# %%
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)


# -----------------------------------------------------
# 6. Final check
# -----------------------------------------------------
print("\nMissing values after imputation:")
print(df.isnull().sum())

print("\nCleaned Dataset:")
print(df)
# Out:
# Missing values after imputation:
# age       0
# salary    0
# city      0
# gender    0
# dtype: int64
#
# Cleaned Dataset:
#     age   salary     city gender
# 0  25.0  50000.0    Delhi      M
# 1  30.0  50000.0  Chennai      F
# 2  30.0  42000.0   Mumbai      F
# 3  40.0  50000.0  Chennai      M
# 4  30.0  60000.0  Chennai      F
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_9456\2815961508.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
